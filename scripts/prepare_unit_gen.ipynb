# %%
import pandas as pd
import os, glob

root = '/mnt/lynx1/datasets/CVSS-C/es-en'

# %%
df_tgt = pd.read_csv(os.path.join(root, 'es', 'test.quant.tsv'), sep='|', header=None)
df_tgt.columns = ['audio_id', 'tgt_unit']
df_tgt['audio_id'] = df_tgt.audio_id.apply(lambda x: x.split('.')[0])
df_tgt.head()
# Out:
#                    audio_id                                           tgt_unit
# 0  common_voice_es_19696046  39 39 951 257 374 772 772 344 6 681 681 133 10...
# 1  common_voice_es_19615622  341 341 520 133 133 257 257 133 133 133 133 13...
# 2  common_voice_es_19960523  39 772 257 497 497 497 497 497 497 497 497 497...
# 3  common_voice_es_19663679  661 661 661 661 661 661 661 661 661 661 661 66...
# 4  common_voice_es_19678892  497 520 520 497 497 497 497 497 497 497 497 49...

# %%
def reduce_tokens(tokens):
    """
    input: a list of (unreduced) speech unit tokens
    output: reduced speech units, the duration label for each unit, as well as the indices that are not reduced.
    """
    dedup_tokens = []
    duration_label = []
    index_to_keep = []
    accu_duration = 1
    for i, token in enumerate(tokens):
        if i == 0:
            dedup_tokens.append(token)
            index_to_keep.append(i)
        else:
            if token != tokens[i - 1]:
                duration_label.append(accu_duration)
                dedup_tokens.append(token)
                index_to_keep.append(i)
                accu_duration = 1
            else:
                accu_duration += 1
    duration_label.append(accu_duration)
    return dedup_tokens, duration_label, index_to_keep

df_tgt['tgt_unit_reduced'] = df_tgt['tgt_unit'].apply(lambda x: ' '.join(reduce_tokens(x.split())[0]))
df_tgt.head()
# Out:
#                    audio_id  \
# 0  common_voice_es_19696046
# 1  common_voice_es_19615622
# 2  common_voice_es_19960523
# 3  common_voice_es_19663679
# 4  common_voice_es_19678892
#
#                                             tgt_unit  \
# 0  39 39 951 257 374 772 772 344 6 681 681 133 10...
# 1  341 341 520 133 133 257 257 133 133 133 133 13...
# 2  39 772 257 497 497 497 497 497 497 497 497 497...
# 3  661 661 661 661 661 661 661 661 661 661 661 66...
# 4  497 520 520 497 497 497 497 497 497 497 497 49...
#
#                                     tgt_unit_reduced
# 0  39 951 257 374 772 344 6 681 133 102 681 216 6...
# 1  341 520 133 257 133 9 133 681 133 681 216 895 ...
# 2  39 772 257 497 987 497 63 665 991 162 73 338 3...
# 3  661 63 922 991 35 421 5 844 316 810 480 243 61...
# 4  497 520 497 184 520 738 681 374 497 63 991 162...

# %%
df_src = pd.read_csv(os.path.join(root, 'en', 'test.quant.tsv'), sep='|', header=None)
df_src.columns = ['audio_id', 'src_unit']
df_src['audio_id'] = df_src.audio_id.apply(lambda x: x.split('.')[0])
df_src['src_unit_reduced'] = df_src['src_unit'].apply(lambda x: ' '.join(reduce_tokens(x.split())[0]))
df_src.head()
# Out:
#                    audio_id  \
# 0  common_voice_es_19724164
# 1  common_voice_es_19645907
# 2  common_voice_es_19744104
# 3  common_voice_es_19118696
# 4  common_voice_es_19638183
#
#                                             src_unit  \
# 0  63 665 780 531 531 531 534 534 948 86 470 152 ...
# 1  63 63 991 821 821 534 485 86 319 416 416 416 4...
# 2  63 63 662 662 244 583 15 333 333 212 455 409 5...
# 3  63 665 202 393 946 734 734 259 781 781 303 303...
# 4  63 63 991 162 116 116 281 281 384 384 384 879 ...
#
#                                     src_unit_reduced
# 0  63 665 780 531 534 948 86 470 152 784 173 641 ...
# 1  63 991 821 534 485 86 319 416 426 647 167 761 ...
# 2  63 662 244 583 15 333 212 455 409 501 137 74 6...
# 3  63 665 202 393 946 734 259 781 303 485 948 813...
# 4  63 991 162 116 281 384 879 70 219 522 67 940 1...

# %%
df = pd.merge(df_src, df_tgt, on='audio_id')
df.head()
# Out:
#                    audio_id  \
# 0  common_voice_es_19724164
# 1  common_voice_es_19645907
# 2  common_voice_es_19744104
# 3  common_voice_es_19118696
# 4  common_voice_es_19638183
#
#                                             src_unit  \
# 0  63 665 780 531 531 531 534 534 948 86 470 152 ...
# 1  63 63 991 821 821 534 485 86 319 416 416 416 4...
# 2  63 63 662 662 244 583 15 333 333 212 455 409 5...
# 3  63 665 202 393 946 734 734 259 781 781 303 303...
# 4  63 63 991 162 116 116 281 281 384 384 384 879 ...
#
#                                     src_unit_reduced  \
# 0  63 665 780 531 534 948 86 470 152 784 173 641 ...
# 1  63 991 821 534 485 86 319 416 426 647 167 761 ...
# 2  63 662 244 583 15 333 212 455 409 501 137 74 6...
# 3  63 665 202 393 946 734 259 781 303 485 948 813...
# 4  63 991 162 116 281 384 879 70 219 522 67 940 1...
#
#                                             tgt_unit  \
# 0  102 520 520 520 588 360 681 681 681 681 497 17...
# 1  102 158 158 360 497 497 497 497 497 497 497 49...
# 2  39 497 497 497 497 497 497 681 997 997 682 371...
# 3  661 28 951 951 6 300 63 63 63 63 63 63 63 63 6...
# 4  497 588 588 588 588 588 520 520 520 520 386 59...
#
#                                     tgt_unit_reduced
# 0  102 520 588 360 681 497 17 681 497 681 520 681...
# 1  102 158 360 497 264 63 922 780 294 314 853 319...
# 2  39 497 681 997 682 371 111 666 371 786 132 644...
# 3  661 28 951 6 300 63 644 991 35 421 190 843 100...
# 4  497 588 520 386 596 704 520 499 804 604 804 70...

# %%
df_orig = df[['audio_id', 'src_unit', 'tgt_unit']]
df_orig['src_n_frames'] = df_orig.src_unit.apply(lambda x: len(x.split()))
df_orig['tgt_n_frames'] = df_orig.tgt_unit.apply(lambda x: len(x.split()))
# reorder columns
df_orig = df_orig[['audio_id', 'src_unit', 'src_n_frames', 'tgt_unit', 'tgt_n_frames']]
df_orig.to_csv(os.path.join(root, 'es/orig_unit/test.tsv'), sep='\t', header=False, index=False)
# Out:
# /tmp/ipykernel_2706411/611004922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orig['src_n_frames'] = df_orig.src_unit.apply(lambda x: len(x.split()))

# %%
df_reduced = df[['audio_id', 'src_unit_reduced', 'tgt_unit_reduced']]
df_reduced['src_n_frames'] = df_reduced.src_unit_reduced.apply(lambda x: len(x.split()))
df_reduced['tgt_n_frames'] = df_reduced.tgt_unit_reduced.apply(lambda x: len(x.split()))
# reorder columns
df_reduced = df_reduced[['audio_id', 'src_unit_reduced', 'src_n_frames', 'tgt_unit_reduced', 'tgt_n_frames']]
df_reduced.to_csv(os.path.join(root, 'es/reduce_unit/test.tsv'), sep='\t', header=False, index=False)
# Out:
# /tmp/ipykernel_2706411/2196089276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced['src_n_frames'] = df_reduced.src_unit_reduced.apply(lambda x: len(x.split()))

# %%
for split in ['train', 'dev']:
    df_tgt = pd.read_csv(os.path.join(root, 'es', f'{split}.quant.tsv'), sep='|', header=None)
    df_tgt.columns = ['audio_id', 'tgt_unit']
    df_tgt['audio_id'] = df_tgt.audio_id.apply(lambda x: x.split('.')[0])
    df_tgt['tgt_unit_reduced'] = df_tgt['tgt_unit'].apply(lambda x: ' '.join(reduce_tokens(x.split())[0]))

    df_src = pd.read_csv(os.path.join(root, 'en', f'{split}.quant.tsv'), sep='|', header=None)
    df_src.columns = ['audio_id', 'src_unit']
    df_src['audio_id'] = df_src.audio_id.apply(lambda x: x.split('.')[0])
    df_src['src_unit_reduced'] = df_src['src_unit'].apply(lambda x: ' '.join(reduce_tokens(x.split())[0]))

    df = pd.merge(df_src, df_tgt, on='audio_id')

    df_orig = df[['audio_id', 'src_unit', 'tgt_unit']]
    df_orig['src_n_frames'] = df_orig.src_unit.apply(lambda x: len(x.split()))
    df_orig['tgt_n_frames'] = df_orig.tgt_unit.apply(lambda x: len(x.split()))
    # reorder columns
    df_orig = df_orig[['audio_id', 'src_unit', 'src_n_frames', 'tgt_unit', 'tgt_n_frames']]
    df_orig.to_csv(os.path.join(root, 'es/orig_unit', f'{split}.tsv'), sep='\t', header=False, index=False)

    df_reduced = df[['audio_id', 'src_unit_reduced', 'tgt_unit_reduced']]
    df_reduced['src_n_frames'] = df_reduced.src_unit_reduced.apply(lambda x: len(x.split()))
    df_reduced['tgt_n_frames'] = df_reduced.tgt_unit_reduced.apply(lambda x: len(x.split()))
    # reorder columns
    df_reduced = df_reduced[['audio_id', 'src_unit_reduced', 'src_n_frames', 'tgt_unit_reduced', 'tgt_n_frames']]
    df_reduced.to_csv(os.path.join(root, 'es/reduce_unit', f'{split}.tsv'), sep='\t', header=False, index=False)
# Out:
# /tmp/ipykernel_2706411/445646541.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orig['src_n_frames'] = df_orig.src_unit.apply(lambda x: len(x.split()))
# /tmp/ipykernel_2706411/445646541.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced['src_n_frames'] = df_reduced.src_unit_reduced.apply(lambda x: len(x.split()))
# /tmp/ipykernel_2706411/445646541.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orig['src_n_frames'] = df_orig.src_unit.apply(lambda x: len(x.split()))
# /tmp/ipykernel_2706411/445646541.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced['src_n_frames'] = df_reduced.src_unit_reduced.apply(lambda x: len(x.split()))

# %%
filepath = '../exps/exp0/cvss/es-en/test.en.tsv'

with open(filepath, 'r') as f:
    lines = f.readlines()[1:]
lines = [line.strip().split('\t') for line in lines]
df = pd.DataFrame(lines, columns=['src_audio', 'src_n_frames'])

filepath_tgt = '../exps/exp0/cvss/es-en/test.es.tsv'
with open(filepath_tgt, 'r') as f:
    lines_tgt = f.readlines()[1:]
lines_tgt = [line.strip().split('\t') for line in lines_tgt]
df_tgt = pd.DataFrame(lines_tgt, columns=['tgt_audio', 'tgt_n_frames'])


df_tgt.head()
# Out:
#                       tgt_audio tgt_n_frames
# 0  common_voice_es_19696046.mp3       360846
# 1  common_voice_es_19615622.mp3       235278
# 2  common_voice_es_19960523.mp3       333198
# 3  common_voice_es_19663679.mp3       307854
# 4  common_voice_es_19678892.mp3       391950

# %%
df['audio_id'] = df['src_audio'].apply(lambda x: x.split('.')[0])
df['merge_id'] = df['audio_id'].apply(lambda x: x.split('.')[0])
df_tgt['merge_id'] = df_tgt['tgt_audio'].apply(lambda x: x.split('.')[0])

df2 = pd.merge(df, df_tgt, on='merge_id', how='left')
# drop rows with NaN
df2 = df2.dropna()
df2 = df2.drop(columns=['merge_id'])
# rearrange columns
df2 = df2[['audio_id', 'src_audio', 'src_n_frames', 'tgt_audio', 'tgt_n_frames']]
df2.head()
# Out:
#                    audio_id                         src_audio src_n_frames  \
# 0  common_voice_es_19599731  common_voice_es_19599731.mp3.wav        96300
# 1  common_voice_es_19762450  common_voice_es_19762450.mp3.wav        70200
# 2  common_voice_es_19942021  common_voice_es_19942021.mp3.wav        88200
# 3  common_voice_es_19969702  common_voice_es_19969702.mp3.wav       101100
# 4  common_voice_es_18758543  common_voice_es_18758543.mp3.wav        65700
#
#                       tgt_audio tgt_n_frames
# 0  common_voice_es_19599731.mp3       383886
# 1  common_voice_es_19762450.mp3       291726
# 2  common_voice_es_19942021.mp3       237582
# 3  common_voice_es_19969702.mp3       370062
# 4  common_voice_es_18758543.mp3       230670

# %%
df2.to_csv('/mnt/lynx1/datasets/CVSS-C/es-en/es/reduce_unit/test.tsv', sep='\t', header=None, index=None)

# %%
# do the same for test -> train, dev

for split in ['train', 'dev']:
    filepath = f'../exps/exp0/cvss/es-en/{split}.en.tsv'
    with open(filepath, 'r') as f:
        lines = f.readlines()[1:]
    lines = [line.strip().split('\t') for line in lines]
    df = pd.DataFrame(lines, columns=['src_audio', 'src_n_frames'])
    
    filepath_tgt = f'../exps/exp0/cvss/es-en/{split}.es.tsv'
    with open(filepath_tgt, 'r') as f:
        lines_tgt = f.readlines()[1:]
    
    lines_tgt = [line.strip().split('\t') for line in lines_tgt]
    df_tgt = pd.DataFrame(lines_tgt, columns=['tgt_audio', 'tgt_n_frames'])
    
    df['audio_id'] = df['src_audio'].apply(lambda x: x.split('.')[0])
    df['merge_id'] = df['audio_id'].apply(lambda x: x.split('.')[0])
    df_tgt['merge_id'] = df_tgt['tgt_audio'].apply(lambda x: x.split('.')[0])
    
    df2 = pd.merge(df, df_tgt, on='merge_id', how='left')
    # drop rows with NaN
    df2 = df2.dropna()
    df2 = df2.drop(columns=['merge_id'])
    # rearrange columns
    df2 = df2[['audio_id', 'src_audio', 'src_n_frames', 'tgt_audio', 'tgt_n_frames']]
    df2.to_csv(f'/mnt/lynx1/datasets/CVSS-C/es-en/es/reduce_unit/{split}.tsv', sep='\t', header=None, index=None)

# %%
import os, glob
import pandas as pd

root = '/mnt/lynx1/datasets/CVSS-C/es-en'

df = pd.read_csv(
    os.path.join(root, "en2es/diff_unit_vae_50/test.tsv"), sep="\t"
)

df.head()
# Out:
#                          id  \
# 0  common_voice_es_19645907
# 1  common_voice_es_19744104
# 2  common_voice_es_19118696
# 3  common_voice_es_19638183
# 4  common_voice_es_18376911
#
#                                            src_audio  src_n_frames  \
# 0  63 991 821 534 485 86 319 416 426 647 167 761 ...           143
# 1  63 662 244 583 15 333 212 455 409 501 137 74 6...           177
# 2  63 665 202 393 946 734 259 781 303 485 948 813...            74
# 3  63 991 162 116 281 384 879 70 219 522 67 940 1...           176
# 4  63 991 479 330 647 167 173 896 627 470 821 677...            71
#
#                                            tgt_audio  tgt_n_frames
# 0  102 158 360 497 264 63 922 780 294 314 853 319...           165
# 1  39 497 681 386 682 371 111 666 735 786 132 644...           232
# 2  661 28 951 6 63 644 991 35 421 190 843 100 629...           125
# 3  497 588 520 386 804 704 520 499 804 604 804 70...           255
# 4  497 17 264 63 644 254 504 773 8 778 311 182 70...           103

# %%
df_trans = pd.read_csv(os.path.join(root, "es/test.tsv"), sep="\t")
df_trans['id'] = df_trans['path'].apply(lambda x: x.split('.')[0])
df_trans.head()
# Out:
#                                            client_id  \
# 0  0003b969350f5308dc7347c574bc291834f38fdd92a286...
# 1  009891ef9a0c11e1b21a9d8a8318c493382963c9eac3ab...
# 2  00b0a5cf01f152b2b6771f16e34118a1d95e29716e4c86...
# 3  00de0234aec2cb4d2268ef5b5ba1d72d84ce36fa032096...
# 4  00f3644640cf32c29fda40403d82ca131e97d93e92cb79...
#
#                            path  \
# 0  common_voice_es_19698530.mp3
# 1  common_voice_es_19987333.mp3
# 2  common_voice_es_19691402.mp3
# 3  common_voice_es_19966634.mp3
# 4  common_voice_es_19600147.mp3
#
#                                             sentence  up_votes  down_votes  \
# 0          Habita en aguas poco profundas y rocosas.         2           1
# 1  Opera principalmente vuelos de cabotaje y regi...         2           1
# 2   Para visitar contactar primero con la dirección.         2           0
# 3  Realizó los estudios primarios en Francia, par...         2           1
# 4  En los años que siguieron, este trabajo Espart...         2           0
#
#         age gender    accent                        id
# 0  thirties   male  mexicano  common_voice_es_19698530
# 1       NaN    NaN       NaN  common_voice_es_19987333
# 2       NaN    NaN       NaN  common_voice_es_19691402
# 3       NaN    NaN       NaN  common_voice_es_19966634
# 4       NaN    NaN       NaN  common_voice_es_19600147

# %%
df = pd.merge(df, df_trans[['id', 'sentence']], on='id', how='left')

# place 'sentence' column 3rd from the beginning
cols = df.columns.tolist()
cols = cols[:1] + [cols[-1]] + cols[1:-1]
df = df[cols]
df.head()
# Out:
#                          id  \
# 0  common_voice_es_19645907
# 1  common_voice_es_19744104
# 2  common_voice_es_19118696
# 3  common_voice_es_19638183
# 4  common_voice_es_18376911
#
#                                             sentence  \
# 0  Se graduó como ingeniero civil en la Universid...
# 1  En ellos se solía citar a pensadores, filósofo...
# 2       Las hojas tienen dos foliolos y un zarcillo.
# 3  A continuación, se hizo amigo de Johannes Kepl...
# 4            A quien mucho miente, le huye la gente.
#
#                                            src_audio  \
# 0  63 991 821 534 485 86 319 416 426 647 167 761 ...
# 1  63 662 244 583 15 333 212 455 409 501 137 74 6...
# 2  63 665 202 393 946 734 259 781 303 485 948 813...
# 3  63 991 162 116 281 384 879 70 219 522 67 940 1...
# 4  63 991 479 330 647 167 173 896 627 470 821 677...
#
#                                           sentence_y  src_n_frames  \
# 0  Se graduó como ingeniero civil en la Universid...           143
# 1  En ellos se solía citar a pensadores, filósofo...           177
# 2       Las hojas tienen dos foliolos y un zarcillo.            74
# 3  A continuación, se hizo amigo de Johannes Kepl...           176
# 4            A quien mucho miente, le huye la gente.            71
#
#                                            tgt_audio  tgt_n_frames  \
# 0  102 158 360 497 264 63 922 780 294 314 853 319...           165
# 1  39 497 681 386 682 371 111 666 735 786 132 644...           232
# 2  661 28 951 6 63 644 991 35 421 190 843 100 629...           125
# 3  497 588 520 386 804 704 520 499 804 604 804 70...           255
# 4  497 17 264 63 644 254 504 773 8 778 311 182 70...           103
#
#                                           sentence_x
# 0  Se graduó como ingeniero civil en la Universid...
# 1  En ellos se solía citar a pensadores, filósofo...
# 2       Las hojas tienen dos foliolos y un zarcillo.
# 3  A continuación, se hizo amigo de Johannes Kepl...
# 4            A quien mucho miente, le huye la gente.

# %%
df.to_csv('../exps/exp0/cvss/es-en/eval.tsv', sep='\t', index=None)
